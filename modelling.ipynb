# %% [markdown]
# # Exploring and modelling

# %% [markdown]
#  - I want to find features to use in a clustering model, perhaps combined with a dimensionality reduction tool like PCA/TSNE/UMAP
#  - If I had more time I would be using Bokeh and streamlit

# %%
import pandas as pd
import seaborn as sns

# %%
wsl_features = pd.read_csv("./output/agg_features_wsl_90.csv")

# %%
wsl_features.head()
# Out:
#    match_id                        team  ratio_Pass_horizontal_zone_left_wing  \
# 0   3764230     Tottenham Hotspur Women                              0.252485
# 1   3764230         West Ham United LFC                              0.284483
# 2   3764231         Birmingham City WFC                              0.215686
# 3   3764231  Brighton & Hove Albion WFC                              0.310924
# 4   3764232                 Chelsea FCW                              0.275930
#
#    ratio_Pass_horizontal_zone_centre  ratio_Pass_horizontal_zone_right_wing  \
# 0                           0.487078                               0.260437
# 1                           0.454741                               0.260776
# 2                           0.531863                               0.252451
# 3                           0.376050                               0.313025
# 4                           0.452055                               0.272016
#
# ...

# %%
wsl_features.columns
# Out:
# Index(['match_id', 'team', 'ratio_Pass_horizontal_zone_left_wing',
#        'ratio_Pass_horizontal_zone_centre',
#        'ratio_Pass_horizontal_zone_right_wing',
#        'ratio_Pass_vertical_zone_back', 'ratio_Pass_vertical_zone_middle',
#        'ratio_Pass_vertical_zone_forward',
#        'ratio_Pressure_horizontal_zone_left_wing',
#        'ratio_Pressure_horizontal_zone_centre',
#        'ratio_Pressure_horizontal_zone_right_wing',
#        'ratio_Pressure_vertical_zone_back',
#        'ratio_Pressure_vertical_zone_middle',
#        'ratio_Pressure_vertical_zone_forward', 'pass_count', 'shot_count',
#        'dribble_count', 'pass_normalised_count', 'shot_normalised_count',
#        'dribble_normalised_count', 'pass_direction_forward_ratio',
#        'pass_direction_sideways_ratio', 'pass_direction_backward_ratio',
#        'pass_short_ratio', 'pass_medium_ratio', 'pass_long_ratio',
#        'shot_aerial_won_ratio', 'shot_first_time_ratio', 'pass_success_ratio',
# ...

# %% [markdown]
# # Passing

# %%
sns.swarmplot(y="team", x="ratio_Pass_vertical_zone_forward", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='ratio_Pass_vertical_zone_forward', ylabel='team'>

# %%
sns.swarmplot(y="team", x="ratio_Pass_horizontal_zone_centre", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='ratio_Pass_horizontal_zone_centre', ylabel='team'>

# %%
sns.swarmplot(y="team", x="ratio_Pass_horizontal_zone_left_wing", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='ratio_Pass_horizontal_zone_left_wing', ylabel='team'>

# %%
sns.swarmplot(y="team", x="pass_direction_forward_ratio", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='pass_direction_forward_ratio', ylabel='team'>

# %%
sns.swarmplot(y="team", x="pass_normalised_count", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='pass_normalised_count', ylabel='team'>

# %%
sns.swarmplot(y="team", x="pass_long_ratio", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='pass_long_ratio', ylabel='team'>

# %%
sns.swarmplot(y="team", x="pass_success_ratio", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='pass_success_ratio', ylabel='team'>

# %%
sns.scatterplot(x="pass_long_ratio", y="pass_success_ratio", hue="team", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='pass_long_ratio', ylabel='pass_success_ratio'>

# %% [markdown]
# # Pressure

# %%
sns.swarmplot(y="team", x="ratio_Pressure_vertical_zone_back", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='ratio_Pressure_vertical_zone_back', ylabel='team'>

# %%
sns.swarmplot(y="team", x="ratio_Pressure_vertical_zone_middle", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='ratio_Pressure_vertical_zone_middle', ylabel='team'>

# %%
sns.swarmplot(y="team", x="ratio_Pressure_vertical_zone_forward", data=wsl_features)
# Out:
# <AxesSubplot:xlabel='ratio_Pressure_vertical_zone_forward', ylabel='team'>

# %% [markdown]
#  - There are some matches where teams are playing lots of long balls
